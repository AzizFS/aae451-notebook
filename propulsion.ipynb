# %% [markdown]
# ## Task list:
# ### 1- Finish python code:
# ### 1.1 - mission profile and historical mission profiles (thrust energy) and thrust to weight and total thrust energy
# ### 1.2 - batteries and esc and more motors
# ### 1.3 - weights
# ### 1.4 - check slides and assignment paper (make sure everything is accounted for)
# ### 2- check javaprop and gold m
# ### 3 - Prof. Goppert's code gave the ideal properties for motors
# ### 4 - maybe using optimization algorithms is better
# ### 5 - manufacturing vs test

# %%
from IPython.display import Image, IFrame, Math

dc_motor_eq = Image(filename='propstuff/dcmotorequations.png')
propparam = Image(filename='propstuff/propparam.png')
static_thrust = Image(filename='propstuff/staticthrust.png')
system_model = Image(filename='propstuff/systemmodel.png')
approx_prop_model = Image(filename='propstuff/approxpropmodel.png')
electric_prop_model = Image(filename='propstuff/Electric Propulsion Model.png')
images = [system_model, electric_prop_model, dc_motor_eq, propparam, static_thrust, approx_prop_model]

for image in images:
    display(image)

# %%
import pandas as pd

data = pd.read_excel('propstuff/dbt_inventory.xlsx', sheet_name='Motor')
data.head(26) # -1 for max?
# Out:
#     Line  Quantity               Brand            Model              Color  \
# 0      1       1.0                 NTM            42-58       Black/silver
# 1      2       1.0              Hacker          A30-14M       Purple/black
# 2      3       1.0                 Axi          5320/18        Gold/Orange
# 3      4       1.0            Sunnysky          X3525-7        Black/Black
# 4      5       2.0             E-flite         Power 46  Blue/Black/Silver
# 5      6       2.0             Turnigy   Aerodrive 3542      Silver/Silver
# 6      7       1.0  Greatplane Rimfire   1.60 63-62-250         Black/Gold
# 7      8       1.0             T motor        MN4010-11       Black/Silver
# 8      9       2.0            Scorpion        S-2215-18       Black/Orange
# 9     10       1.0             Turnigy   Aerodrive 3548      Silver/Silver
# 10    11       3.0             Turnigy              G32       Black/Silver
# 11    12       1.0             E-flite         Power 32  Blue/Black/Silver
# 12    13       4.0             Turnigy       Vspec 2205        Black Black
# 13    14       1.0                 NTM  Propdrive 35-48       Black/Silver
# 14    15       1.0                 KDE           2814XF       Black/Silver
# 15    16       1.0             T motor           AT3530         Black/Grey
# 16    17       1.0            E-flite          Park 450  Blue/Black/Silver
# 17    18       1.0                 NTM  Propdrive 28-26       Black/Silver
# 18    19       1.0            Scorpion          HK-4035         Black/Gold
# 19    20       1.0              Hacker           A10-7L       Purple/black
# 20    21       1.0                 Axi          2212/34        Gold/Orange
# 21    22       1.0             E-flite         Park 400  Blue/Black/Silver
# 22    23       1.0            Heli-Max     HMXG8003 480       Black/Purple
# 23    24       1.0                Emax           CF2812        Gray/Orange
# 24    25       1.0             E-flite         Power 32  Blue/Black/Silver
# 25    26       1.0             E-flite         Power 25  Blue/Black/Silver
#
#     KV [RPM/V]  Resistance [Ohms]  No load current at 10 V [A]  \
# 0        500.0            0.14400                         1.60
# 1       3600.0            0.19000                         3.10
# 2        370.0            0.23000                         1.40
# 3        520.0            0.02200                         1.30
# 4        670.0            0.04000                         3.90
# 5       1250.0            0.02200                          NaN
# 6        250.0                NaN                         1.50
# 7        475.0            0.09800                         0.80
# 8       1126.0            0.07800                         0.73
# 9       1050.0            0.01600                          NaN
# 10       600.0            0.03600                         1.30
# 11       770.0            0.02000                         2.40
# 12      2350.0            0.07700                         0.60
# 13       900.0                NaN                          NaN
# 14       775.0            0.06900                         0.50
# 15       700.0            0.01800                         0.90
# 16       890.0            0.20000                         0.70
# 17      1100.0                NaN                          NaN
# 18       800.0            0.01000                         2.50
# 19      2200.0            0.11000                         1.10
# 20       710.0            0.34500                         0.40
# 21       740.0            0.26000                         0.70
# 22      4300.0            0.01648                         4.96
# 23      1600.0                NaN                          NaN
# 24       770.0            0.02000                         2.40
# 25       870.0            0.03000                         2.40
#
#     LiPo Cells min [#]  Min Voltage [V]  ...  Power Diff [%]  \
# 0                  5.0             18.5  ...        0.356923
# 1                  3.0             11.1  ...        1.352000
# 2                  6.0             22.2  ...        0.135135
# 3                  6.0             22.2  ...        0.331387
# 4                  4.0             14.8  ...        0.443750
# 5                  3.0             11.1  ...        0.201589
# 6                  9.0             33.3  ...       -0.092800
# 7                  4.0             14.8  ...        1.240000
# 8                  3.0             11.1  ...        0.400000
# 9                  3.0             11.1  ...        0.024390
# 10                 3.0             11.1  ...        0.260000
# 11                 3.0             11.1  ...        0.260000
# 12                 3.0             11.1  ...        0.000000
# 13                 3.0             11.1  ...        0.133742
# 14                 3.0             11.1  ...        0.413084
# 15                 3.0             11.1  ...        0.170000
# 16                 2.0              7.4  ...        0.296000
# 17                 3.0             11.1  ...        0.158621
# 18                10.0             37.0  ...        0.200000
# 19                 2.0              7.4  ...       -0.216000
# 20                 3.0             11.1  ...        0.260000
# 21                 2.0              7.4  ...       -0.100000
# 22                 3.0             11.1  ...        0.260000
# 23                 2.0              7.4  ...        0.620000
# 24                 3.0             11.1  ...        0.260000
# 25                 3.0             11.1  ...       -0.022545
#
#     Can Diameter [mm]  Bullet connector diameter [mm]                Notes  \
# 0                42.0                               4                  NaN
# 1                35.0                            Bare   6.7:1 Gearbox att.
# 2                63.0                               5                  NaN
# 3                42.5                             3.5                  NaN
# 4                50.0                               3                  NaN
# 5                37.0                               4                  NaN
# 6                63.0                            Bare                  NaN
# 7                40.0                             3.5                  NaN
# 8                27.9                               3                  NaN
# 9                37.0                            Bare                  NaN
# 10               26.0                               3   Pusher config only
# 11               42.0                               4                  NaN
# 12               27.0               Soldered with ESC      *2xCW and 2xCCW
# 13               35.0                               3                  NaN
# 14               35.5                             3.5                  NaN
# 15               43.0                             NaN                  NaN
# 16               28.0                               3                  NaN
# 17               28.0                               3                  NaN
# 18               48.9                               5                  NaN
# 19               21.0                            Bare                  NaN
# 20               27.7                            Bare                  NaN
# 21               28.0                               3                  NaN
# 22               29.0                            Bare                  NaN
# 23               28.5                             3.5                  NaN
# 24               42.0                             3.5  Missing stock label
# 25               35.0                             NaN  Missing stock label
#
#     efficiency                  Unnamed: 20  Unnamed: 21 Unnamed: 22  \
# 0          NaN  With the idea that KvKt = 1          NaN         NaN
# 1          NaN                          NaN          NaN         NaN
# 2          NaN                          NaN          NaN         NaN
# 3          NaN                          NaN          NaN         NaN
# 4          NaN                          NaN          NaN         NaN
# 5          NaN                          NaN          NaN         NaN
# 6          NaN                          NaN          NaN         NaN
# 7          NaN                          NaN          NaN         NaN
# 8          NaN                          NaN          NaN         NaN
# 9          NaN                          NaN          NaN         NaN
# 10         NaN                          NaN          NaN         NaN
# 11         NaN                          NaN          NaN         NaN
# 12         NaN                          NaN          NaN         NaN
# 13         NaN                          NaN          NaN         NaN
# 14         NaN                          NaN          NaN         NaN
# 15         NaN                          NaN          NaN         NaN
# 16         NaN                          NaN          NaN         NaN
# 17         NaN                          NaN          NaN         NaN
# 18         NaN                          NaN          NaN         NaN
# 19         NaN                          NaN          NaN         NaN
# 20         NaN                          NaN          NaN         NaN
# 21         NaN                          NaN          NaN         NaN
# 22         NaN                          NaN          NaN         NaN
# 23         NaN                          NaN          NaN         NaN
# 24         NaN                          NaN          NaN         NaN
# 25         NaN                          NaN          NaN         NaN
#
#    Unnamed: 23  Unnamed: 24
# 0          NaN          NaN
# 1          NaN          NaN
# 2          NaN          NaN
# 3          NaN          NaN
# 4          NaN          NaN
# 5          NaN          NaN
# 6          NaN          NaN
# 7          NaN          NaN
# 8          NaN          NaN
# 9          NaN          NaN
# 10         NaN          NaN
# 11         NaN          NaN
# 12         NaN          NaN
# 13         NaN          NaN
# 14         NaN          NaN
# 15         NaN          NaN
# 16         NaN          NaN
# 17         NaN          NaN
# 18         NaN          NaN
# 19         NaN          NaN
# 20         NaN          NaN
# 21         NaN          NaN
# 22         NaN          NaN
# 23         NaN          NaN
# 24         NaN          NaN
# 25         NaN          NaN
#
# [26 rows x 25 columns]

# %% [markdown]
# ## From MIT

# %%
IFrame('propstuff/motorprop.pdf', width = 1000, height = 1000)
# Out:
#         <iframe
#             width="1000"
#             height="1000"
#             src="propstuff/motorprop.pdf"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# $cd = 0.058$
# $rho = 1.225$
# $vel = 8 m/s$
# $A = 0.38 m^2$

# %%
# %%capture 
## hiding output (graphs)
# %run prop_match.py
## !!! Put proper values below
desired_thrust = (0.5)*(1.225)*(8**2)*(0.38)*(0.058)
print(out(thrust = 0.1))

## using historical data and interpolation?
##NOTE this appends propeller name, max eff, rpm at max eff, T and Q (torque) to an excel file 'efficiency.xlsx'

# %% [markdown]
# $\text{Parameters we need to set are the velocity (at what speed will our aircraft go?), thrust required for the mission, and motor applied voltage.}$

# %% [markdown]
# ## Motors

# %%
eta_m = lambda kv, R, i0, v: (1 - (i0*R)/(v - omega / kv))*(omega / (v*kv))
Q_m = lambda kv, R, i0, v: ((v - (omega / kv)) * (1 / R) - i0) * (1 / kv)
Pshaft = lambda kv, R, i0, v: ((v - (omega / kv)) * (1 / R) - i0) * (omega / kv)

# %% [markdown]
# $$\eta_m(\Omega, v) = [1 + \frac{i_0 R}{\frac{\Omega}{K_v} - v}]\frac{\Omega}{v K_v}$$
# $$$$
# $$Q_m(\Omega, v) = [(v - \frac{\Omega}{K_v})\frac{1}{R} - i_0](\frac{1}{K_v}) $$
# $$$$
# $$P_{\text{shaft}}(\Omega, v) = [(v - \frac{\Omega}{K_v})\frac{1}{R} - i_0](\frac{\Omega}{K_v})$$
# ### When $\ \eta_m = 0$:
# $$\Omega = K_v(v - i_0R)$$

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

num = 26 ## number of entries in the excel file
motor_names = np.array(data['Model'])[0:num]
lines = np.array([i for i in range(num)])
kv = np.array(data['KV [RPM/V]'])[0:num] / 60 # equation requires rad/s/volt
R = np.array(data['Resistance [Ohms]'])[0:num]
i0 = np.array(data['No load current at 10 V [A]'])[0:num]
#v = np.random.randint(high= 11, low= 8, size=3, replace=False)
v = [5,7,10] ##check battery voltages

rgb = ['blue', 'red', 'black']

functions = {'eta': eta_m, 'Q': Q_m, 'Pshaft': Pshaft}

for line in lines[0:2]: ## to keep it brief for now!!!
    if kv[line] is str:
        pass
    elif R[line] is str:
        pass
    elif i0[line] is str:
        pass
    else:
        for fun in functions:
            plt.figure(figsize=(8,8))
            plt.title(motor_names[line])
            for j in range(len(v)):
                omega = np.linspace(0, kv[line]*(v[j] - i0[line]*R[line]), 100)

                func = np.array(functions[fun](kv = kv[line], R=R[line], i0=i0[line], v=v[j]))

                plt.plot(omega, func, color=rgb[j], label= 'v = ' + str(v[j]))
                plt.xlabel('rps')
                plt.ylabel(fun)
                if fun == 'eta':
                    eta_max = np.nanmax(func)
                    rps_max = omega[np.where(func == eta_max)][0]
                    plt.text(rps_max, np.nanmax(func), \
                            'omega = {:.2f}'.format(rps_max) + '\n' + 'eta = {:.2f}'.format(eta_max))
            plt.legend()

# %% [markdown]
# ## Propellers

# %% [markdown]
# $\text{We can determined voltage from required thrust:}$
# $$$$
# $$ (1)\text{ Terrible model: }\ T = C_T \rho n^2 D^4 \qquad (2) \text{ Or: } T = \frac{1}{2} \rho (\Omega r)^2 \pi r^2 C_T = \frac{1}{2} \rho V^2 \pi r^2 \frac{C_T(\lambda, Re)}{\lambda^2}$$

# %% [markdown]
# ### $\text{From aerodynamics T = 4 N, and a D = 5 in.}$

# %%
T = lambda rho, R, Ct: (0.5)*(rho)*((omega*R)**2)*(np.pi)*(R**2)*(Ct)

# %% [markdown]
# $\text{Use:} \quad v(\Omega, Q) = (K_vQ + i_0)R + \frac{\Omega}{K_v} \quad \text{to find required voltage. Another method is graphical and detailed in the document above.}$

# %%
##
num_prop = 30 # how many propellers?
eff = pd.read_excel('propstuff/efficiency.xlsx')
eff.head(num_prop) # -1 for max?
# Out:
#          prop_name  max_eta_prop        omega         T         Q  \
# 0       apce_9x4.5      0.606004  4694.755756  0.694805  0.018667
# 1       apce_11x10      0.754006  2523.018018  0.916901  0.036767
# 2         mae_10x7      0.713008  2828.262262  0.677846  0.025676
# 3        grsn_11x6      0.609627  3789.031031  1.033626  0.034121
# 4        gwssf_9x7      0.722124  3623.898899  0.736453  0.021495
# 5         apce_8x6      0.671860  4444.555556  1.003827  0.025653
# 6        grcp_11x8      0.733296  2477.981982  0.514342  0.021624
# 7         magf_9x7      0.720388  3318.654655  0.557123  0.017800
# 8       apcsp_11x4      0.488031  4809.847848  1.601527  0.052111
# 9       apcsf_11x7      0.718659  2918.334334  1.056474  0.038454
# 10       apcsp_9x6      0.665328  3583.866867  0.582085  0.018693
# 11       grcp_10x6      0.576991  3964.171171  0.848562  0.028332
# 12      gwssf_10x8      0.692012  3473.778779  1.045131  0.033226
# 13      apcsp_11x8      0.723080  2528.022022  0.651929  0.027271
# 14        grsn_9x5      0.579193  4804.843844  0.986718  0.027026
# 15       apcsp_8x6      0.598997  3924.139139  0.446715  0.014504
# 16       apce_10x5      0.630536  3939.151151  0.676056  0.020878
# 17     apcsf_8x3.8      0.577827  5000.000000  0.581450  0.015359
# 18    apcsf_10x4.7      0.641184  4329.463463  1.431615  0.039406
# 19     apce_11x8.5      0.660920  3959.167167  2.798819  0.081808
# 20       apcsp_8x8      0.595468  2993.394394  0.263405  0.011294
# 21  apccf_7.4x8.25      0.656953  4434.547548  1.003242  0.026309
# 22       rusp_11x4      0.480895  5000.000000  1.610784  0.051101
# 23       gwsdd_9x5      0.613255  5000.000000  0.934214  0.023299
# 24      apcsp_10x7      0.627366  3098.478478  0.544845  0.021418
# 25      apcsp_11x7      0.699019  2908.326326  0.934658  0.035122
# 26        mas_11x7      0.519419  3048.438438  0.489714  0.023611
# 27       apcsp_8x7      0.627413  3974.179179  0.594301  0.018208
# 28        magf_8x4      0.562037  5000.000000  0.447398  0.012117
# 29        grsn_9x7      0.658839  3979.183183  1.419436  0.041393
#
#     diameter [in]
# 0             9.0
# 1            11.0
# 2            10.0
# 3            11.0
# 4             9.0
# 5             8.0
# 6            11.0
# 7             9.0
# 8            11.0
# 9            11.0
# 10            9.0
# 11           10.0
# 12           10.0
# 13           11.0
# 14            9.0
# 15            8.0
# 16           10.0
# 17            8.0
# 18           10.0
# 19           11.0
# 20            8.0
# 21            7.4
# 22           11.0
# 23            9.0
# 24           10.0
# 25           11.0
# 26           11.0
# 27            8.0
# 28            8.0
# 29            9.0

# %%
names = eff['prop_name'][0:num_prop]
omegas = eff['omega'][0:num_prop]
max_eta = eff['max_eta_prop'][0:num_prop]
T = eff['T'][0:num_prop]
Q = eff['Q'][0:num_prop]
quantities = {'max_eta':max_eta, 'T': T, 'Q': Q}

for quantity in quantities:
    plt.figure(figsize=(12,8))
    plt.scatter(omegas, quantities[quantity])
    plt.xlabel('rps')
    plt.ylabel(quantity)
    for i, txt in enumerate(names):
        plt.annotate(txt, (omegas[i], quantities[quantity][i]))

# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
# %run propdata.py
out(8.0, 4, 1, 17)

# %%
o = {'1':{'a':0},'2':{'a':0}}
#a = [[s for s in o[m][s]] for m in range(2)]
enumerate(list(o.keys()))
